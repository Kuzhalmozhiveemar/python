# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn

# %%
data=pd.read_csv('F:/PROJECTS/THEFT/theft.csv',engine='python')
data.head()
# Out:
#                    Area_Name  Year                  Group_Name  \
# 0  Andaman & Nicobar Islands  2001  AT1-Motor Cycles/ Scooters
# 1             Andhra Pradesh  2001  AT1-Motor Cycles/ Scooters
# 2          Arunachal Pradesh  2001  AT1-Motor Cycles/ Scooters
# 3                      Assam  2001  AT1-Motor Cycles/ Scooters
# 4                      Bihar  2001  AT1-Motor Cycles/ Scooters
#
#               Sub_Group_Name  Theft_Coordinated/Traced  Theft_Recovered  \
# 0  1. Motor Cycles/ Scooters                         0              4.0
# 1  1. Motor Cycles/ Scooters                       136           1311.0
# 2  1. Motor Cycles/ Scooters                         0             21.0
# 3  1. Motor Cycles/ Scooters                         0             94.0
# 4  1. Motor Cycles/ Scooters                        44            205.0
#
#    Theft_Stolen        lat        lng
# 0             4  12.382571  92.822911
# 1          2725  17.389716  78.466689
# ...

# %%
import seaborn as sns
sns.set(style="whitegrid")
tips = sns.load_dataset("tips")
ax = sns.barplot(x="day", y="total_bill", data=tips)
plt.show()
# Out:
# C:\Users\kuzhal\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.set(style="whitegrid")
ax = sns.barplot(x="day", y="total_bill", hue="sex", data=tips)
plt.show()
# Out:
# C:\Users\kuzhal\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
grouped=data.groupby(['Area_Name','Year'],as_index=False)['Theft_Stolen'].sum()
grouped
# Out:
#                      Area_Name  Year  Theft_Stolen
# 0    Andaman & Nicobar Islands  2001             8
# 1    Andaman & Nicobar Islands  2002             4
# 2    Andaman & Nicobar Islands  2003            10
# 3    Andaman & Nicobar Islands  2004            18
# 4    Andaman & Nicobar Islands  2005            12
# 5    Andaman & Nicobar Islands  2006            12
# 6    Andaman & Nicobar Islands  2007            16
# 7    Andaman & Nicobar Islands  2008            22
# 8    Andaman & Nicobar Islands  2009            20
# 9    Andaman & Nicobar Islands  2010            44
# 10              Andhra Pradesh  2001          6230
# 11              Andhra Pradesh  2002          6900
# 12              Andhra Pradesh  2003          9464
# 13              Andhra Pradesh  2004          9482
# 14              Andhra Pradesh  2005         10930
# 15              Andhra Pradesh  2006         10940
# 16              Andhra Pradesh  2007         12618
# ...

# %%
ax = sns.barplot(x="Area_Name", y="Theft_Stolen", hue="Year", data=grouped)
plt.show()

# %%
data.Theft_Stolen.sort_values(ascending=False).head(20)
data.columns
#data [ (data.Theft_Stolen > 5000 ) & (data.Area_Name == 'Maharashtra') ]
#data[data.Theft_Stolen > 5000]
data[(data.Area_Name == 'Madhya Pradesh') & (data.Area_Name == 'Uttar Pradesh') & (data.Area_Name == 'Uttarkhand')].head()
# Out:
# Empty DataFrame
# Columns: [Area_Name, Year, Group_Name, Sub_Group_Name, Theft_Coordinated/Traced, Theft_Recovered, Theft_Stolen, lat, lng]
# Index: []

# %%
orders = pd.read_table('F:/PROJECTS/THEFT/theft.csv')

# %%
data['Area_Name'].unique().tolist()
# Out:
# ['Andaman & Nicobar Islands',
#  'Andhra Pradesh',
#  'Arunachal Pradesh',
#  'Assam',
#  'Bihar',
#  'Chandigarh',
#  'Chhattisgarh',
#  'Dadra & Nagar Haveli',
#  'Delhi',
#  'Goa',
#  'Gujarat',
#  'Haryana',
#  'Himachal Pradesh',
#  'Jammu & Kashmir',
#  'Jharkhand',
#  'Karnataka',
#  'Kerala',
#  'Madhya Pradesh',
#  'Maharashtra',
#  'Manipur',
#  'Meghalaya',
#  'Mizoram',
#  'Nagaland',
#  'Odisha',
#  'Puducherry',
#  'Punjab',
#  'Rajasthan',
#  'Sikkim',
#  'Tamil Nadu',
#  'Tripura',
#  'Uttar Pradesh',
#  'Uttarakhand',
#  'West Bengal',
#  'Daman & Diu',
#  'Lakshadweep']

# %%
data['Area_Name'].nunique()
# Out:
# 35

# %%
data.head()
# Out:
#                    Area_Name  Year                  Group_Name  \
# 0  Andaman & Nicobar Islands  2001  AT1-Motor Cycles/ Scooters
# 1             Andhra Pradesh  2001  AT1-Motor Cycles/ Scooters
# 2          Arunachal Pradesh  2001  AT1-Motor Cycles/ Scooters
# 3                      Assam  2001  AT1-Motor Cycles/ Scooters
# 4                      Bihar  2001  AT1-Motor Cycles/ Scooters
#
#               Sub_Group_Name  Theft_Coordinated/Traced  Theft_Recovered  \
# 0  1. Motor Cycles/ Scooters                         0              4.0
# 1  1. Motor Cycles/ Scooters                       136           1311.0
# 2  1. Motor Cycles/ Scooters                         0             21.0
# 3  1. Motor Cycles/ Scooters                         0             94.0
# 4  1. Motor Cycles/ Scooters                        44            205.0
#
#    Theft_Stolen        lat        lng
# 0             4  12.382571  92.822911
# 1          2725  17.389716  78.466689
# ...

# %%
data['Location'] = data.Group_Name + ', ' + data.Sub_Group_Name
data.head()
# Out:
#                    Area_Name  Year                  Group_Name  \
# 0  Andaman & Nicobar Islands  2001  AT1-Motor Cycles/ Scooters
# 1             Andhra Pradesh  2001  AT1-Motor Cycles/ Scooters
# 2          Arunachal Pradesh  2001  AT1-Motor Cycles/ Scooters
# 3                      Assam  2001  AT1-Motor Cycles/ Scooters
# 4                      Bihar  2001  AT1-Motor Cycles/ Scooters
#
#               Sub_Group_Name  Theft_Coordinated/Traced  Theft_Recovered  \
# 0  1. Motor Cycles/ Scooters                         0              4.0
# 1  1. Motor Cycles/ Scooters                       136           1311.0
# 2  1. Motor Cycles/ Scooters                         0             21.0
# 3  1. Motor Cycles/ Scooters                         0             94.0
# 4  1. Motor Cycles/ Scooters                        44            205.0
#
#    Theft_Stolen        lat        lng  \
# 0             4  12.382571  92.822911
# 1          2725  17.389716  78.466689
# ...

# %%
data.describe()
# Out:
#               Year  Theft_Coordinated/Traced  Theft_Recovered  Theft_Stolen  \
# count  1865.000000               1865.000000      1863.000000   1865.000000
# mean   2005.564075                 60.712064       293.769189   1029.431635
# std       2.853598                245.548399       673.606886   2399.389932
# min    2001.000000                  0.000000         0.000000      0.000000
# 25%    2003.000000                  0.000000         3.000000      7.000000
# 50%    2006.000000                  0.000000        27.000000     80.000000
# 75%    2008.000000                 14.000000       172.000000    521.000000
# max    2010.000000               2985.000000      5453.000000  18605.000000
#
#                lat          lng
# count  1865.000000  1865.000000
# mean     23.258330    81.880607
# std       6.270115     7.227676
# min       8.537102    72.672217
# 25%      20.215132    76.758725
# 50%      23.907813    78.466689
# 75%      27.360485    88.352765
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1865 entries, 0 to 1864
# Data columns (total 10 columns):
# Area_Name                   1865 non-null object
# Year                        1865 non-null int64
# Group_Name                  1865 non-null object
# Sub_Group_Name              1865 non-null object
# Theft_Coordinated/Traced    1865 non-null int64
# Theft_Recovered             1863 non-null float64
# Theft_Stolen                1865 non-null int64
# lat                         1865 non-null float64
# lng                         1865 non-null float64
# Location                    1865 non-null object
# dtypes: float64(3), int64(3), object(4)
# memory usage: 145.8+ KB

# %%
data=pd.read_csv('F:/PROJECTS/THEFT/theft.csv',usecols=['Area_Name','Theft_Stolen','Year','lat','lng'],engine='python')

# %%
data.rename(columns={'lat':'Latitude', 'lng':'Longitude'}, inplace=True)
data.columns
# Out:
# Index(['Area_Name', 'Year', 'Theft_Stolen', 'Latitude', 'Longitude'], dtype='object')

# %%
data.columns = data.columns.str.replace(' ', '_')
data.columns
# Out:
# Index(['Area_Name', 'Year', 'Theft_Stolen', 'Latitude', 'Longitude'], dtype='object')

# %%
data.drop('Longitude', axis=1, inplace=True)
data.head()
# Out:
#                    Area_Name  Year  Theft_Stolen   Latitude
# 0  Andaman & Nicobar Islands  2001             4  12.382571
# 1             Andhra Pradesh  2001          2725  17.389716
# 2          Arunachal Pradesh  2001            27  27.360485
# 3                      Assam  2001           205  26.427872
# 4                      Bihar  2001           946  25.402971

# %%
data.drop([0], axis=0, inplace=True)
data.head()
#row gets removed!
#When referring to rows or columns with the axis parameter:

#axis 0 refers to rows
#axis 1 refers to columns
# Out:
#            Area_Name  Year  Theft_Stolen   Latitude
# 1     Andhra Pradesh  2001          2725  17.389716
# 2  Arunachal Pradesh  2001            27  27.360485
# 3              Assam  2001           205  26.427872
# 4              Bihar  2001           946  25.402971
# 5         Chandigarh  2001           281  30.742600

# %%
data.Theft_Stolen.sort_values(ascending=False).head()
# Out:
# 1850    18605
# 1816    18236
# 1781    16909
# 1862    16705
# 326     15126
# Name: Theft_Stolen, dtype: int64

# %%
#entire dataframe gets sorted
data.sort_values('Theft_Stolen').head()
# Out:
#               Area_Name  Year  Theft_Stolen   Latitude
# 824   Arunachal Pradesh  2007             0  27.360485
# 1400  Arunachal Pradesh  2007             0  27.360485
# 777        Chhattisgarh  2005             0  20.886032
# 776          Chandigarh  2005             0  30.742600
# 775               Bihar  2005             0  25.402971

# %%
data[data.Theft_Stolen >= 5000].Area_Name.unique().tolist()
#data.loc[data.Theft_Stolen >= 5000, 'Area_Name'].unique().tolist() same thing using loc
# Out:
# ['Maharashtra',
#  'Gujarat',
#  'Madhya Pradesh',
#  'Rajasthan',
#  'Uttar Pradesh',
#  'Karnataka',
#  'Andhra Pradesh',
#  'Delhi',
#  'Haryana',
#  'Tamil Nadu']

# %%
data[(data.Theft_Stolen >=5000) | (data.Area_Name == 'Madhya Pradesh')].head()
# Out:
#          Area_Name  Year  Theft_Stolen   Latitude
# 17  Madhya Pradesh  2001          3756  23.480726
# 18     Maharashtra  2001          6244  18.516962
# 44         Gujarat  2002          5318  23.193680
# 51  Madhya Pradesh  2002          4225  23.480726
# 52     Maharashtra  2002          6777  18.516962

# %%
data[data.Area_Name.isin(['Delhi', 'Madhya Pradesh', 'Gujarat'])].head(10)
# Out:
#           Area_Name  Year  Theft_Stolen   Latitude
# 8             Delhi  2001          3185  28.645944
# 10          Gujarat  2001          4830  23.193680
# 17   Madhya Pradesh  2001          3756  23.480726
# 42            Delhi  2002          3291  28.645944
# 44          Gujarat  2002          5318  23.193680
# 51   Madhya Pradesh  2002          4225  23.480726
# 75            Delhi  2003          3360  28.645944
# 77          Gujarat  2003          6131  23.193680
# 85   Madhya Pradesh  2003          4291  23.480726
# 109           Delhi  2004          4342  28.645944

# %%
data.Theft_Stolen.mean()
# Out:
# 1029.9817596566525

# %%
data[data.Area_Name=='Madhya Pradesh'].Theft_Stolen.mean()
# Out:
# 2825.090909090909

# %%
data.groupby('Area_Name').Theft_Stolen.sum()
# Out:
# Area_Name
# Andaman & Nicobar Islands       162
# Andhra Pradesh               113618
# Arunachal Pradesh              1658
# Assam                         22236
# Bihar                         45754
# Chandigarh                    14842
# Chhattisgarh                  33310
# Dadra & Nagar Haveli            446
# Daman & Diu                     510
# Delhi                        197330
# Goa                            4404
# Gujarat                      158396
# Haryana                      118926
# Himachal Pradesh               4750
# Jammu & Kashmir               13088
# Jharkhand                     26826
# Karnataka                    134254
# Kerala                        37480
# Lakshadweep                      22
# Madhya Pradesh               155380
# Maharashtra                  262564
# Manipur                        3388
# Meghalaya                      2348
# Mizoram                         868
# Nagaland                       4014
# Odisha                        33144
# ...

# %%
data.groupby('Area_Name').Theft_Stolen.agg(['count', 'mean', 'min', 'max'])
# Out:
#                            count         mean  min    max
# Area_Name
# Andaman & Nicobar Islands     27     6.000000    1     22
# Andhra Pradesh                60  1893.633333    0   8257
# Arunachal Pradesh             57    29.087719    0    139
# Assam                         60   370.600000    0   1878
# Bihar                         59   775.491525    0   4271
# Chandigarh                    59   251.559322    0   1117
# Chhattisgarh                  60   555.166667    0   2188
# Dadra & Nagar Haveli          39    11.435897    1     37
# Daman & Diu                   37    13.783784    0     36
# Delhi                         60  3288.833333    5  15031
# Goa                           48    91.750000    1    372
# Gujarat                       60  2639.933333    1  11145
# Haryana                       60  1982.100000    2  11398
# Himachal Pradesh              60    79.166667    0    334
# Jammu & Kashmir               59   221.830508    0    968
# ...

# %%
# %matplotlib inline
data.groupby('Area_Name').mean().plot(kind='bar')

# %%
data.Theft_Stolen.plot(kind='hist')

# %%
data.Area_Name.value_counts().plot(kind='bar')

# %%
data.isnull().tail()
data.notnull().tail()
data.isnull().sum()
# Out:
# Area_Name       0
# Year            0
# Theft_Stolen    0
# Latitude        0
# dtype: int64

# %%
data[data.Area_Name.isnull()].head()
# Out:
# Empty DataFrame
# Columns: [Area_Name, Year, Theft_Stolen, Latitude]
# Index: []

# %%
pd.options.display.max_rows = 4000

# %%
data.dropna(subset=['Theft_Stolen', 'Area_Name'], how='any').shape
# Out:
# (1864, 4)

# %%
data['Area_Name'].value_counts().head(35).sort_values()
#set_index,sort_index
# Out:
# Lakshadweep                  11
# Andaman & Nicobar Islands    27
# Sikkim                       33
# Daman & Diu                  37
# Dadra & Nagar Haveli         39
# Tripura                      42
# Puducherry                   46
# Goa                          48
# Uttarakhand                  51
# Mizoram                      54
# Manipur                      54
# Madhya Pradesh               55
# Jharkhand                    55
# Arunachal Pradesh            57
# Tamil Nadu                   59
# Nagaland                     59
# Chandigarh                   59
# Bihar                        59
# Jammu & Kashmir              59
# Chhattisgarh                 60
# Haryana                      60
# Gujarat                      60
# Himachal Pradesh             60
# Kerala                       60
# Assam                        60
# West Bengal                  60
# Meghalaya                    60
# Andhra Pradesh               60
# Maharashtra                  60
# ...

# %%
data.fillna(method='ffill').tail()
data.fillna(method='bfill').tail()
# Out:
#           Area_Name  Year  Theft_Stolen   Latitude
# 1860     Tamil Nadu  2010          5205  13.058099
# 1861        Tripura  2010            50  23.211874
# 1862  Uttar Pradesh  2010         16705  26.838234
# 1863    Uttarakhand  2010           853  30.533333
# 1864    West Bengal  2010          4305  22.550581

# %%
data.loc[index, :]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-37f5652e94da> in <module>()
# ----> 1 data.loc[index, :]
#
# NameError: name 'index' is not defined

# %%
data.loc[1, :]
# Out:
# Area_Name       Andhra Pradesh
# Year                      2001
# Theft_Stolen              2725
# Latitude               17.3897
# Name: 1, dtype: object

# %%
data.loc[1:3,:]
# Out:
#            Area_Name  Year  Theft_Stolen   Latitude
# 1     Andhra Pradesh  2001          2725  17.389716
# 2  Arunachal Pradesh  2001            27  27.360485
# 3              Assam  2001           205  26.427872

# %%
data.loc[:,["Theft_Stolen","Area_Name","Year"]]
# Out:
#       Theft_Stolen                  Area_Name  Year
# 1             2725             Andhra Pradesh  2001
# 2               27          Arunachal Pradesh  2001
# 3              205                      Assam  2001
# 4              946                      Bihar  2001
# 5              281                 Chandigarh  2001
# 6              790               Chhattisgarh  2001
# 7               12       Dadra & Nagar Haveli  2001
# 8             3185                      Delhi  2001
# 9              152                        Goa  2001
# 10            4830                    Gujarat  2001
# 11            1967                    Haryana  2001
# 12              47           Himachal Pradesh  2001
# 13             460            Jammu & Kashmir  2001
# 14             211                  Jharkhand  2001
# 15            3087                  Karnataka  2001
# 16            1038                     Kerala  2001
# 17            3756             Madhya Pradesh  2001
# ...

# %%
data.loc[data.Area_Name == "Madhya Pradesh","Theft_Stolen" ].head()
# Out:
# 17     3756
# 51     4225
# 85     4291
# 118    5481
# 151    5741
# Name: Theft_Stolen, dtype: int64

# %%
data.iloc[:,0]
# Out:
# 1                  Andhra Pradesh
# 2               Arunachal Pradesh
# 3                           Assam
# 4                           Bihar
# 5                      Chandigarh
# 6                    Chhattisgarh
# 7            Dadra & Nagar Haveli
# 8                           Delhi
# 9                             Goa
# 10                        Gujarat
# 11                        Haryana
# 12               Himachal Pradesh
# 13                Jammu & Kashmir
# 14                      Jharkhand
# 15                      Karnataka
# 16                         Kerala
# 17                 Madhya Pradesh
# 18                    Maharashtra
# 19                        Manipur
# 20                      Meghalaya
# 21                        Mizoram
# 22                       Nagaland
# 23                         Odisha
# 24                     Puducherry
# 25                         Punjab
# 26                      Rajasthan
# 27                         Sikkim
# ...

# %%
data.iloc[:, [0, 3]]
# Out:
#                       Area_Name   Latitude
# 1                Andhra Pradesh  17.389716
# 2             Arunachal Pradesh  27.360485
# 3                         Assam  26.427872
# 4                         Bihar  25.402971
# 5                    Chandigarh  30.742600
# 6                  Chhattisgarh  20.886032
# 7          Dadra & Nagar Haveli  20.215132
# 8                         Delhi  28.645944
# 9                           Goa  15.548723
# 10                      Gujarat  23.193680
# 11                      Haryana  28.148731
# 12             Himachal Pradesh  31.155725
# 13              Jammu & Kashmir  34.273129
# 14                    Jharkhand  23.184235
# 15                    Karnataka  12.936827
# 16                       Kerala   8.537102
# 17               Madhya Pradesh  23.480726
# 18                  Maharashtra  18.516962
# 19                      Manipur  24.507121
# 20                    Meghalaya  25.897066
# 21                      Mizoram  23.907813
# ...

# %%
web_stats = {'Day':[1,2,3,4,5,6],
             'Visitors':[43,34,65,56,29,76],
             'Bounce Rate':[65,67,78,65,45,52]}
import pandas as pd
df=pd.DataFrame(web_stats)
df.head()
df.tail(2)
df.set_index('Day',inplace=True)
df.head()
# Out:
#      Bounce Rate  Visitors
# Day
# 1             65        43
# 2             67        34
# 3             78        65
# 4             65        56
# 5             45        29

# %%
import matplotlib.pyplot as plt
from matplotlib import style
style.use('fivethirtyeight')
print(df['Visitors'])
df['Visitors'].plot()
plt.show()
# Out:
# Day
# 1    43
# 2    34
# 3    65
# 4    56
# 5    29
# 6    76
# Name: Visitors, dtype: int64

# %%
data=pd.read_csv('F:/PROJECTS/THEFT/theft.csv',engine='python')
#df.to_csv('newcsv2.csv')
df['Visitors'].to_csv('newcsv.csv')

# %%
df1 = pd.DataFrame({'HPI':[80,85,88,85],
                    'Int_rate':[2, 3, 2, 2],
                    'US_GDP_Thousands':[50, 55, 65, 55]},
                   index = [2001, 2002, 2003, 2004])

df2 = pd.DataFrame({'HPI':[80,85,88,85],
                    'Int_rate':[2, 3, 2, 2],
                    'US_GDP_Thousands':[50, 55, 65, 55]},
                   index = [2005, 2006, 2007, 2008])

df3 = pd.DataFrame({'HPI':[80,85,88,85],
                    'Int_rate':[2, 3, 2, 2],
                    'Low_tier_HPI':[50, 52, 50, 53]},
                   index = [2001, 2002, 2003, 2004])

# %%
con=pd.concat([df1,df2])
con
# Out:
#       HPI  Int_rate  US_GDP_Thousands
# 2001   80         2                50
# 2002   85         3                55
# 2003   88         2                65
# 2004   85         2                55
# 2005   80         2                50
# 2006   85         3                55
# 2007   88         2                65
# 2008   85         2                55

# %%
df4=df1.append(df2)
df4
# Out:
#       HPI  Int_rate  US_GDP_Thousands
# 2001   80         2                50
# 2002   85         3                55
# 2003   88         2                65
# 2004   85         2                55
# 2005   80         2                50
# 2006   85         3                55
# 2007   88         2                65
# 2008   85         2                55

# %%
mer=pd.merge(df1,df2, on=["HPI","Int_rate"])
mer
# Out:
#    HPI  Int_rate  US_GDP_Thousands_x  US_GDP_Thousands_y
# 0   80         2                  50                  50
# 1   85         3                  55                  55
# 2   88         2                  65                  65
# 3   85         2                  55                  55

# %%
import quandl

df=quandl.get("FMAC/HPI_AK", authtoken="nzpfBf66PGzBBGZdzyKc")


print(df.head())
# Out:
#             NSA Value   SA Value
# Date
# 1975-01-31  34.491826  34.690429
# 1975-02-28  34.990303  35.162914
# 1975-03-31  35.501729  35.544504
# 1975-04-30  36.035816  35.922629
# 1975-05-31  36.620436  36.332016

# %%
fiddy_states = pd.read_html('https://simple.wikipedia.org/wiki/List_of_U.S._states')
print(fiddy_states)
# Out:
# [                          Name & Abbr          Cities                  \
#                           Name & Abbr         Capital      Largest[3]
# 0                        Alabama   AL      Montgomery      Birmingham
# 1                         Alaska   AK          Juneau       Anchorage
# 2                        Arizona   AZ         Phoenix         Phoenix
# 3                       Arkansas   AR     Little Rock     Little Rock
# 4                     California   CA      Sacramento     Los Angeles
# 5                       Colorado   CO          Denver          Denver
# 6                    Connecticut   CT        Hartford      Bridgeport
# 7                       Delaware   DE           Dover      Wilmington
# 8                        Florida   FL     Tallahassee    Jacksonville
# 9                        Georgia   GA         Atlanta         Atlanta
# 10                        Hawaii   HI        Honolulu        Honolulu
# ...

# %%
print(fiddy_states[0])
# Out:
#                           Name & Abbr          Cities                  \
#                           Name & Abbr         Capital      Largest[3]
# 0                        Alabama   AL      Montgomery      Birmingham
# 1                         Alaska   AK          Juneau       Anchorage
# 2                        Arizona   AZ         Phoenix         Phoenix
# 3                       Arkansas   AR     Little Rock     Little Rock
# 4                     California   CA      Sacramento     Los Angeles
# 5                       Colorado   CO          Denver          Denver
# 6                    Connecticut   CT        Hartford      Bridgeport
# 7                       Delaware   DE           Dover      Wilmington
# 8                        Florida   FL     Tallahassee    Jacksonville
# 9                        Georgia   GA         Atlanta         Atlanta
# 10                        Hawaii   HI        Honolulu        Honolulu
# ...

# %%
def state_list():
    fiddy_states = pd.read_html('https://simple.wikipedia.org/wiki/List_of_U.S._states')
    return fiddy_states[0][0][1:]

# %%
def HPI_Benchmark():
    df = quandl.get("FMAC/HPI_USA", authtoken="nzpfBf66PGzBBGZdzyKc")
    df["United States"] = (df["United States"]-df["United States"][0]) / df["United States"][0] * 100.0
    return df

# %%
bridge_height = {'meters':[10.26, 10.31, 10.27, 10.22, 10.23, 6212.42, 10.28, 10.25, 10.31]}

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style

style.use('fivethirtyeight')

bridge_height = {'meters':[10.26, 10.31, 10.27, 10.22, 10.23, 6212.42, 10.28, 10.25, 10.31]}
df = pd.DataFrame(bridge_height)

df.plot()
plt.show()

# %%
def mortgage_30y():
    df = quandl.get("FMAC/MORTG", trim_start="1975-01-01", authtoken="nzpfBf66PGzBBGZdzyKc")
    df["Value"] = (df["Value"]-df["Value"][0]) / df["Value"][0] * 100.0
    print(df.head())
    return df

mortgage_30y()
# Out:
#                Value
# Date
# 1975-01-01  0.000000
# 1975-02-01 -3.393425
# 1975-03-01 -5.620361
# 1975-04-01 -6.468717
# 1975-05-01 -5.514316
#                 Value
# Date
# 1975-01-01   0.000000
# 1975-02-01  -3.393425
# 1975-03-01  -5.620361
# 1975-04-01  -6.468717
# 1975-05-01  -5.514316
# 1975-06-01  -5.726405
# 1975-07-01  -5.726405
# 1975-08-01  -5.196182
# 1975-09-01  -3.181336
# 1975-10-01  -2.226935
# 1975-11-01  -2.969247
# 1975-12-01  -3.499470
# 1976-01-01  -4.347826
# 1976-02-01  -6.574761
# 1976-03-01  -7.104984
# 1976-04-01  -7.423118
# 1976-05-01  -6.998940
# 1976-06-01  -6.150583
# 1976-07-01  -5.302227
# 1976-08-01  -4.559915
# 1976-09-01  -4.772004
# 1976-10-01  -5.302227
# 1976-11-01  -6.574761
# 1976-12-01  -6.786850
# 1977-01-01  -7.529162
# 1977-02-01  -8.059385
# 1977-03-01  -7.847296
# 1977-04-01  -7.211029
# 1977-05-01  -6.468717
# 1977-06-01  -6.044539
# ...               ...
# 2014-04-01 -53.976670
# 2014-05-01 -55.567338
# 2014-06-01 -55.885472
# ...
